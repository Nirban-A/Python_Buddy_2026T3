# %% [markdown]
# # Python Basics - Practice Test
# ### Python Buddy · Question Bank
#
# ---
#
# **Instructions:**
# - There are **10 questions** ranging from easy to moderately hard.
# - Complete each function by replacing the `...` with your code.
# - Run the test cell after each question to check your answer.
# - Do **not** modify the test functions.
#
# ---

# %% [markdown]
# ## Question 1 - Easy
# ### Classify a Number
#
# Write a function `classify_number(n)` that returns:
# - `"positive"` if `n > 0`
# - `"negative"` if `n < 0`
# - `"zero"` if `n == 0`
#
# ```python
# classify_number(5)   → "positive"
# classify_number(-3)  → "negative"
# classify_number(0)   → "zero"
# ```

# %%
def classify_number(n: int) -> str:
    '''
    Classify a number as positive, negative, or zero.

    Args:
        n (int): The number to classify.

    Returns:
        str: "positive", "negative", or "zero".
    '''
    ...

# %%
def test_q1():
    assert classify_number(5)    == "positive", "Test 1 failed"
    assert classify_number(-3)   == "negative", "Test 2 failed"
    assert classify_number(0)    == "zero",     "Test 3 failed"
    assert classify_number(100)  == "positive", "Test 4 failed"
    assert classify_number(-999) == "negative", "Test 5 failed"
    print("All tests passed for Question 1!")

test_q1()

# %% [markdown]
# ---
# ## Question 2 - Easy
# ### Sum of Digits
#
# Write a function `sum_of_digits(n)` that returns the sum of the digits of a positive integer `n`.
#
# ```python
# sum_of_digits(123)  → 6
# sum_of_digits(9999) → 36
# sum_of_digits(10)   → 1
# ```

# %%
def sum_of_digits(n: int) -> int:
    '''
    Return the sum of the digits of a positive integer.

    Args:
        n (int): A positive integer.

    Returns:
        int: Sum of all digits.
    '''
    ...

# %%
def test_q2():
    assert sum_of_digits(123)  == 6,  "Test 1 failed"
    assert sum_of_digits(9999) == 36, "Test 2 failed"
    assert sum_of_digits(10)   == 1,  "Test 3 failed"
    assert sum_of_digits(0)    == 0,  "Test 4 failed"
    assert sum_of_digits(7)    == 7,  "Test 5 failed"
    print("All tests passed for Question 2!")

test_q2()

# %% [markdown]
# ---
# ## Question 3 - Easy
# ### Count Vowels in a String
#
# Write a function `count_vowels(s)` that returns the number of vowels (`a, e, i, o, u`) in the string `s`. The check should be case-insensitive.
#
# ```python
# count_vowels("Hello")  → 2
# count_vowels("Python") → 1
# count_vowels("AEIOU")  → 5
# count_vowels("xyz")    → 0
# ```

# %%
def count_vowels(s: str) -> int:
    '''
    Count the number of vowels in a string (case-insensitive).

    Args:
        s (str): The input string.

    Returns:
        int: Number of vowels.
    '''
    ...

# %%
def test_q3():
    assert count_vowels("Hello")  == 2, "Test 1 failed"
    assert count_vowels("Python") == 1, "Test 2 failed"
    assert count_vowels("AEIOU")  == 5, "Test 3 failed"
    assert count_vowels("xyz")    == 0, "Test 4 failed"
    assert count_vowels("")       == 0, "Test 5 failed"
    print("All tests passed for Question 3!")

test_q3()

# %% [markdown]
# ---
# ## Question 4 - Easy
# ### Multiplication Table
#
# Write a function `multiplication_table(n)` that returns a list of strings representing the multiplication table of `n` from 1 to 10.
#
# ```python
# multiplication_table(3)
# → ["3 x 1 = 3", "3 x 2 = 6", ..., "3 x 10 = 30"]
# ```

# %%
def multiplication_table(n: int) -> list:
    '''
    Return the multiplication table of n (1 to 10) as a list of strings.
    Format: "n x i = result"

    Args:
        n (int): The number.

    Returns:
        list: List of 10 strings.
    '''
    ...

# %%
def test_q4():
    result = multiplication_table(3)
    assert len(result) == 10,             "Length should be 10"
    assert result[0]   == "3 x 1 = 3",   "Test 1 failed"
    assert result[9]   == "3 x 10 = 30", "Test 2 failed"
    assert result[4]   == "3 x 5 = 15",  "Test 3 failed"
    result5 = multiplication_table(5)
    assert result5[0]  == "5 x 1 = 5",   "Test 4 failed"
    assert result5[9]  == "5 x 10 = 50", "Test 5 failed"
    print("All tests passed for Question 4!")

test_q4()

# %% [markdown]
# ---
# ## Question 5 - Moderate
# ### Check Armstrong Number
#
# An **Armstrong number** (also called a narcissistic number) is a number equal to the sum of its own digits each raised to the power of the number of digits.
#
# For example: `153 = 1³ + 5³ + 3³ = 1 + 125 + 27 = 153`
#
# Write a function `is_armstrong(n)` that returns `True` if `n` is an Armstrong number.
#
# ```python
# is_armstrong(153)  → True
# is_armstrong(370)  → True
# is_armstrong(100)  → False
# is_armstrong(9)    → True   (single digit: 9¹ = 9)
# ```

# %%
def is_armstrong(n: int) -> bool:
    '''
    Check if n is an Armstrong (narcissistic) number.

    Args:
        n (int): A non-negative integer.

    Returns:
        bool: True if n is an Armstrong number.
    '''
    ...

# %%
def test_q5():
    assert is_armstrong(153)  == True,  "Test 1 failed"
    assert is_armstrong(370)  == True,  "Test 2 failed"
    assert is_armstrong(371)  == True,  "Test 3 failed"
    assert is_armstrong(407)  == True,  "Test 4 failed"
    assert is_armstrong(100)  == False, "Test 5 failed"
    assert is_armstrong(9)    == True,  "Test 6 failed"
    assert is_armstrong(10)   == False, "Test 7 failed"
    print("All tests passed for Question 5!")

test_q5()

# %% [markdown]
# ---
# ## Question 6 - Moderate
# ### Count Consecutive Character Groups
#
# Write a function `count_groups(s)` that returns the number of groups of consecutive identical characters in a string.
#
# ```python
# count_groups("aabbbcc")  → 3   # "aa", "bbb", "cc"
# count_groups("abcd")     → 4   # each character is its own group
# count_groups("aaaa")     → 1   # one group
# count_groups("")         → 0
# ```

# %%
def count_groups(s: str) -> int:
    '''
    Count the number of consecutive identical character groups in s.

    Args:
        s (str): The input string.

    Returns:
        int: Number of groups.
    '''
    ...

# %%
def test_q6():
    assert count_groups("aabbbcc") == 3, "Test 1 failed"
    assert count_groups("abcd")    == 4, "Test 2 failed"
    assert count_groups("aaaa")    == 1, "Test 3 failed"
    assert count_groups("")        == 0, "Test 4 failed"
    assert count_groups("aabbaa")  == 3, "Test 5 failed"
    assert count_groups("a")       == 1, "Test 6 failed"
    print("All tests passed for Question 6!")

test_q6()

# %% [markdown]
# ---
# ## Question 7 - Moderate
# ### Collatz Sequence Length
#
# The **Collatz sequence** starting from a positive integer `n` is defined as:
# - If `n` is even: next term = `n // 2`
# - If `n` is odd: next term = `3 * n + 1`
# - Stop when `n` reaches 1
#
# Write a function `collatz_length(n)` that returns the number of steps to reach 1 (not counting the starting number).
#
# ```python
# collatz_length(1)  → 0   (already at 1)
# collatz_length(6)  → 8   (6→3→10→5→16→8→4→2→1)
# collatz_length(27) → 111
# ```

# %%
def collatz_length(n: int) -> int:
    '''
    Return the number of steps in the Collatz sequence to reach 1.

    Args:
        n (int): A positive integer.

    Returns:
        int: Number of steps to reach 1.
    '''
    ...

# %%
def test_q7():
    assert collatz_length(1)  == 0,   "Test 1 failed"
    assert collatz_length(6)  == 8,   "Test 2 failed"
    assert collatz_length(27) == 111, "Test 3 failed"
    assert collatz_length(2)  == 1,   "Test 4 failed"
    assert collatz_length(4)  == 2,   "Test 5 failed"
    print("All tests passed for Question 7!")

test_q7()

# %% [markdown]
# ---
# ## Question 8 - Moderate
# ### Caesar Cipher
#
# Write a function `caesar_encrypt(text, shift)` that encrypts a string using the Caesar cipher - shift each letter forward by `shift` positions in the alphabet (wrap around from z to a). Non-alphabetic characters remain unchanged. Preserve the original case.
#
# ```python
# caesar_encrypt("Hello, World!", 3)  → "Khoor, Zruog!"
# caesar_encrypt("abc", 1)            → "bcd"
# caesar_encrypt("xyz", 3)            → "abc"   (wraps around)
# caesar_encrypt("ABC", 2)            → "CDE"
# ```

# %%
def caesar_encrypt(text: str, shift: int) -> str:
    '''
    Encrypt text using Caesar cipher with the given shift.
    Preserve case; leave non-alphabetic characters unchanged.

    Args:
        text  (str): The plaintext.
        shift (int): Number of positions to shift.

    Returns:
        str: The encrypted text.
    '''
    ...

# %%
def test_q8():
    assert caesar_encrypt("Hello, World!", 3) == "Khoor, Zruog!", "Test 1 failed"
    assert caesar_encrypt("abc", 1)           == "bcd",           "Test 2 failed"
    assert caesar_encrypt("xyz", 3)           == "abc",           "Test 3 failed"
    assert caesar_encrypt("ABC", 2)           == "CDE",           "Test 4 failed"
    assert caesar_encrypt("a1b2c3", 1)        == "b1c2d3",        "Test 5 failed"
    assert caesar_encrypt("ZzAa", 1)          == "AaBb",          "Test 6 failed"
    print("All tests passed for Question 8!")

test_q8()

# %% [markdown]
# ---
# ## Question 9 - Moderate-Hard
# ### Run-Length Encoding
#
# Write a function `run_length_encode(s)` that compresses a string using run-length encoding: replace consecutive runs of the same character with `character + count`. If a character appears only once, just write the character (no `1`).
#
# ```python
# run_length_encode("aabbbcccc")  → "a2b3c4"
# run_length_encode("abcd")       → "abcd"    (no repetitions)
# run_length_encode("aaabba")     → "a3b2a"
# run_length_encode("")           → ""
# ```

# %%
def run_length_encode(s: str) -> str:
    '''
    Compress a string using run-length encoding.
    Single characters are written without a count.

    Args:
        s (str): The input string.

    Returns:
        str: The run-length encoded string.
    '''
    ...

# %%
def test_q9():
    assert run_length_encode("aabbbcccc") == "a2b3c4", "Test 1 failed"
    assert run_length_encode("abcd")      == "abcd",   "Test 2 failed"
    assert run_length_encode("aaabba")    == "a3b2a",  "Test 3 failed"
    assert run_length_encode("")          == "",       "Test 4 failed"
    assert run_length_encode("a")         == "a",      "Test 5 failed"
    assert run_length_encode("aaa")       == "a3",     "Test 6 failed"
    print("All tests passed for Question 9!")

test_q9()

# %% [markdown]
# ---
# ## Question 10 - Moderate-Hard
# ### Number to Words (1–99)
#
# Write a function `number_to_words(n)` that converts an integer `n` (1–99) to its English word representation.
#
# ```python
# number_to_words(5)   → "five"
# number_to_words(13)  → "thirteen"
# number_to_words(20)  → "twenty"
# number_to_words(42)  → "forty two"
# number_to_words(99)  → "ninety nine"
# ```
#
# **Hint:** Use a dictionary or lists for the word mappings.

# %%
def number_to_words(n: int) -> str:
    '''
    Convert an integer (1-99) to its English word form.
    Two-word numbers are separated by a space (e.g. "forty two").

    Args:
        n (int): An integer from 1 to 99.

    Returns:
        str: English word representation.
    '''
    ...

# %%
def test_q10():
    assert number_to_words(5)  == "five",        "Test 1 failed"
    assert number_to_words(13) == "thirteen",    "Test 2 failed"
    assert number_to_words(20) == "twenty",      "Test 3 failed"
    assert number_to_words(42) == "forty two",   "Test 4 failed"
    assert number_to_words(99) == "ninety nine", "Test 5 failed"
    assert number_to_words(11) == "eleven",      "Test 6 failed"
    assert number_to_words(30) == "thirty",      "Test 7 failed"
    assert number_to_words(71) == "seventy one", "Test 8 failed"
    print("All tests passed for Question 10!")

test_q10()
